# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernest-Trevis/SemProject_MLEngine/blob/main/MentalHealthSurvey_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2. For each dataset, identify at least one variable that would serve as the expected
# output of the final application.

# %% [markdown]
# Dataset 1: MentalHealthSurvey.csv
# *   stress_relief_activities
# *   gender
# *   age
# *   academic_workload
# *   academic_pressure
#
# Dataset 2: academic Stress level.csv
# *   Rate your academic stress index

# %% [markdown]
# 3. Select the most appropriate dataset and carry out some data exploration by
# answering these questions in a Colab Notebook. Each question/response should
# appear on its own cell. (Using Dataset 1: MentalHealthSurvey.csv)

# %% [markdown]
# a) How many rows and columns are contained in the dataset?
# 88 rows and 21 columns

# %% [markdown]
# b) What datatypes are contained in the dataset?
# *  Integers
# *  Strings
# *  Floating point

# %% [markdown]
# c) Is the dataset complete? Yes

# %% [markdown]
# d) Slice out the first 15 rows and last 20 rows and merge them into a new
# dataframe titled “df_sample”. Display this new dataframe.
#
# ---

# %%
import pandas as pd
import numpy as np
from google.colab import files

uploaded = files.upload()
df = pd.read_csv('MentalHealthSurvey.csv')
df_sample = pd.concat([df.head(15), df.tail(20)])

print(df_sample)
# Out:
#      <input type="file" id="files-06851b37-3f43-4d4e-82ce-3fa90675936b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06851b37-3f43-4d4e-82ce-3fa90675936b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
